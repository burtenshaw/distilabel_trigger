# %%
import argilla as rg

client = rg.Argilla(api_key="argilla.apikey", api_url="http://localhost:6900")

# %%
from datetime import datetime

dataset = rg.Dataset(
    name=f"triggers_{datetime.now().strftime('%Y%m%d%H%M%S')}",
    settings=rg.Settings(
        fields=[
            rg.TextField("persona"),
            rg.TextField("instruction"),
            rg.TextField("response1"),
            rg.TextField("response2"),
        ],
        questions=[
            rg.LabelQuestion(name="respond", labels=["yes", "no"], required=True),
            rg.TextQuestion(name="improved_instruction", required=False),
            rg.TextQuestion(name="response1_rationale", required=False),
            rg.TextQuestion(name="response2_rationale", required=False),
            rg.RatingQuestion(
                name="response1_rating", values=[1, 2, 3, 4, 5], required=False
            ),
            rg.RatingQuestion(
                name="response2_rating", values=[1, 2, 3, 4, 5], required=False
            ),
        ],
    ),
)

# %%
dataset.create()
# Out:
# Dataset(id=UUID('7d528756-d877-4b35-9c29-69acf82a657e') inserted_at=datetime.datetime(2024, 8, 14, 8, 8, 17, 956135) updated_at=datetime.datetime(2024, 8, 14, 8, 8, 18, 178416) name='triggers_20240814100816' status='ready' guidelines=None allow_extra_metadata=False distribution=OverlapTaskDistributionModel(strategy='overlap', min_submitted=1) workspace_id=UUID('735cae0d-eb08-45c3-ad79-0a11ad4dd2c2') last_activity_at=datetime.datetime(2024, 8, 14, 8, 8, 18, 178416))

# %%
from datasets import load_dataset

ds = load_dataset("proj-persona/PersonaHub", "instruction")
MAX_RECORDS = 1000
records_to_upload = []
for sample in ds["train"].to_iterable_dataset():
    record=rg.Record(
                fields={
                    "persona": sample["input persona"],
                    "instruction": sample["synthesized text"],
                    "response1": "",
                    "response2": "",
                },
                id=str(hash(sample["synthesized text"])),
            )
    records_to_upload.append(record)
    if len(records_to_upload) == MAX_RECORDS:
        break
dataset.records.log(records=records_to_upload)
# Out:
# Sending records...: 4batch [00:01,  3.31batch/s]
# DatasetRecords(Dataset(id=UUID('7d528756-d877-4b35-9c29-69acf82a657e') inserted_at=datetime.datetime(2024, 8, 14, 8, 8, 17, 956135) updated_at=datetime.datetime(2024, 8, 14, 8, 8, 18, 178416) name='triggers_20240814100816' status='ready' guidelines=None allow_extra_metadata=False distribution=OverlapTaskDistributionModel(strategy='overlap', min_submitted=1) workspace_id=UUID('735cae0d-eb08-45c3-ad79-0a11ad4dd2c2') last_activity_at=datetime.datetime(2024, 8, 14, 8, 8, 18, 178416)))

# %%
list(
    dataset.records(
        query=rg.Query(filter=rg.Filter(conditions=[("respond.response", "==", "yes")]))
    )
)
# Out:
# []

# %%
from distilabel.llms import InferenceEndpointsLLM
from distilabel.steps.tasks import TextGeneration

import requests


def update_record_fields(record_id, updated_fields):
    url = f"http://localhost:6900/api/v1/records/{record_id}"
    headers = {
        "accept": "application/json",
        "X-Argilla-Api-Key": "argilla.apikey",
        "Content-Type": "application/json",
    }
    data = {"fields": updated_fields}
    response = requests.patch(url, headers=headers, json=data)
    return response.json()


def delete_response(response_id):
    url = f"http://localhost:6900/api/v1/responses/{response_id}"
    headers = {
        "accept": "application/json",
        "X-Argilla-Api-Key": "argilla.apikey",
        "Content-Type": "application/json",
    }
    response = requests.delete(url, headers=headers)
    return response.json()


def respond_to_record(record: rg.Record):
    llama31 = TextGeneration(
        name="text-generation",
        llm=InferenceEndpointsLLM(
            model_id="meta-llama/Meta-Llama-3.1-8B-Instruct",
            tokenizer_id="meta-llama/Meta-Llama-3.1-8B-Instruct",
        ),
    )
    llama31.load()

    gemma_tiny = TextGeneration(
        name="text-generation",
        llm=InferenceEndpointsLLM(
            model_id="google/gemma-1.1-7b-it",
            tokenizer_id="google/gemma-1.1-7b-it",
        ),
    )
    gemma_tiny.load()

    responses = []
    for task in [llama31, gemma_tiny]:
        print(task.name)
        output = list(task.process([{"instruction": record.fields["instruction"]}]))[
            0
        ][0]
        generation = output["generation"]
        responses.append(generation)
    return responses

# %%
from distilabel.llms import InferenceEndpointsLLM
from distilabel.steps.tasks import UltraFeedback


def add_feedback_suggestions(record, response_1, response_2) -> None:
    ultrafeedback = UltraFeedback(
        aspect="overall-rating",
        llm=InferenceEndpointsLLM(
            model_id="meta-llama/Meta-Llama-3.1-70B-Instruct",
            tokenizer_id="meta-llama/Meta-Llama-3.1-70B-Instruct",
        ),
    )
    ultrafeedback.load()
    response = ultrafeedback.process(
        [
            {
                "instruction": "trivia questions",
                "generations": [
                    response_1,
                    response_2,
                ],
            }
        ],
    )
    response = list(response)[0][0]
    ratings = response["ratings"]
    rationales = response["rationales"]

    for n, (rating, rationale) in enumerate(zip(ratings, rationales)):
        record.suggestions.add(
            suggestion=rg.Suggestion(
                question_name=f"response{n+1}_rating",
                value=rating,
            )
        )
        record.suggestions.add(
            suggestion=rg.Suggestion(
                question_name=f"response{n+1}_rationale",
                value=rationale,
            )
        )

    for response in record.responses["respond"]:
        response.status = "draft"
    return record

# %%
def respond_to_good_instructions() -> None:
    updated_records = []
    for record in dataset.records(
        query=rg.Query(filter=rg.Filter(conditions=[("respond.response", "==", "yes")]))
    ):
        response_1, response_2 = respond_to_record(record=record)
        updated_fields = dict(record.fields)
        updated_fields["response1"] = response_1
        updated_fields["response2"] = response_2
        update_record_fields(
            record_id=record._server_id,
            updated_fields=updated_fields,
        )
        updated_record = add_feedback_suggestions(
            record=record, response_1=response_1, response_2=response_2
        )

        updated_records.append(updated_record)
    dataset.records.log(updated_records)


respond_to_good_instructions()
# Out:
# Step 'text-generation' hasn't received a pipeline, and it hasn't been created within a `Pipeline` context. Please, use `with Pipeline() as pipeline:` and create the step within the context.
# Since the `base_url=https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3.1-8B-Instruct` is available and either one of `model_id` or `endpoint_name` is also provided, the `base_url` will either be ignored or overwritten with the one generated from either of those args, for serverless or dedicated inference endpoints, respectively.
# Step 'text-generation' hasn't received a pipeline, and it hasn't been created within a `Pipeline` context. Please, use `with Pipeline() as pipeline:` and create the step within the context.
# Since the `base_url=https://api-inference.huggingface.co/models/google/gemma-1.1-7b-it` is available and either one of `model_id` or `endpoint_name` is also provided, the `base_url` will either be ignored or overwritten with the one generated from either of those args, for serverless or dedicated inference endpoints, respectively.
# text-generation
# text-generation
# Step 'None' hasn't received a pipeline, and it hasn't been created within a `Pipeline` context. Please, use `with Pipeline() as pipeline:` and create the step within the context.
# Since the `base_url=https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3.1-70B-Instruct` is available and either one of `model_id` or `endpoint_name` is also provided, the `base_url` will either be ignored or overwritten with the one generated from either of those args, for serverless or dedicated inference endpoints, respectively.
# DatasetRecords: The provided batch size 256 was normalized. Using value 1.
# Sending records...: 100%|██████████| 1/1 [00:00<00:00, 14.82batch/s]

# %%
def get_dataset_progress(dataset_id):
    url = f"http://localhost:6900/api/v1/datasets/{dataset_id}/progress"
    headers = {
        "accept": "application/json",
        "X-Argilla-Api-Key": "argilla.apikey",
        "Content-Type": "application/json",
    }
    response = requests.get(url, headers=headers)
    return response.json()


_completed = 0

while True:
    dataset_progress = get_dataset_progress(dataset_id=dataset.id)
    completed = dataset_progress["completed"]
    if completed > _completed:
        print(f"Completed {completed} records")
        _completed = completed
        respond_to_good_instructions()
# Out:
# Step 'text-generation' hasn't received a pipeline, and it hasn't been created within a `Pipeline` context. Please, use `with Pipeline() as pipeline:` and create the step within the context.
# Since the `base_url=https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3.1-8B-Instruct` is available and either one of `model_id` or `endpoint_name` is also provided, the `base_url` will either be ignored or overwritten with the one generated from either of those args, for serverless or dedicated inference endpoints, respectively.
# Completed 1 records
# Step 'text-generation' hasn't received a pipeline, and it hasn't been created within a `Pipeline` context. Please, use `with Pipeline() as pipeline:` and create the step within the context.
# Since the `base_url=https://api-inference.huggingface.co/models/google/gemma-1.1-7b-it` is available and either one of `model_id` or `endpoint_name` is also provided, the `base_url` will either be ignored or overwritten with the one generated from either of those args, for serverless or dedicated inference endpoints, respectively.
# text-generation
# text-generation
# Step 'None' hasn't received a pipeline, and it hasn't been created within a `Pipeline` context. Please, use `with Pipeline() as pipeline:` and create the step within the context.
# Since the `base_url=https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3.1-70B-Instruct` is available and either one of `model_id` or `endpoint_name` is also provided, the `base_url` will either be ignored or overwritten with the one generated from either of those args, for serverless or dedicated inference endpoints, respectively.
# Step 'text-generation' hasn't received a pipeline, and it hasn't been created within a `Pipeline` context. Please, use `with Pipeline() as pipeline:` and create the step within the context.
# Since the `base_url=https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3.1-8B-Instruct` is available and either one of `model_id` or `endpoint_name` is also provided, the `base_url` will either be ignored or overwritten with the one generated from either of those args, for serverless or dedicated inference endpoints, respectively.
# Step 'text-generation' hasn't received a pipeline, and it hasn't been created within a `Pipeline` context. Please, use `with Pipeline() as pipeline:` and create the step within the context.
# Since the `base_url=https://api-inference.huggingface.co/models/google/gemma-1.1-7b-it` is available and either one of `model_id` or `endpoint_name` is also provided, the `base_url` will either be ignored or overwritten with the one generated from either of those args, for serverless or dedicated inference endpoints, respectively.
# text-generation
# text-generation
# Step 'None' hasn't received a pipeline, and it hasn't been created within a `Pipeline` context. Please, use `with Pipeline() as pipeline:` and create the step within the context.
# Since the `base_url=https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3.1-70B-Instruct` is available and either one of `model_id` or `endpoint_name` is also provided, the `base_url` will either be ignored or overwritten with the one generated from either of those args, for serverless or dedicated inference endpoints, respectively.
# DatasetRecords: The provided batch size 256 was normalized. Using value 2.
# Sending records...: 100%|██████████| 1/1 [00:00<00:00, 11.51batch/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:15                                                                                   │
# │                                                                                                  │
# │   12 _completed = 0                                                                              │
# │   13                                                                                             │
# │   14 while True:                                                                                 │
# │ ❱ 15 │   dataset_progress = get_dataset_progress(dataset_id=dataset.id)                          │
# │   16 │   completed = dataset_progress["completed"]                                               │
# │   17 │   if completed > _completed:                                                              │
# │   18 │   │   print(f"Completed {completed} records")                                             │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │     add_feedback_suggestions = <function add_feedback_suggestions at 0x1392f0400>            │ │
# │ │                       client = <argilla.client.Argilla object at 0x13a467850>                │ │
# │ │                    completed = 0                                                             │ │
# │ │                      dataset = Dataset(id=UUID('3453d11b-f50a-4f62-8d38-09ac3e99bc00')       │ │
# │ │                                inserted_at=datetime.datetime(2024, 8, 13, 13, 3, 43, 20806)  │ │
# │ │                                updated_at=datetime.datetime(2024, 8, 13, 13, 3, 43, 277352)  │ │
# │ │                                name='triggers_20240813150340' status='ready' guidelines=None │ │
# │ │                                allow_extra_metadata=False                                    │ │
# │ │                                distribution=OverlapTaskDistributionModel(strategy='overlap', │ │
# │ │                                min_submitted=1)                                              │ │
# │ │                                workspace_id=UUID('735cae0d-eb08-45c3-ad79-0a11ad4dd2c2')     │ │
# │ │                                last_activity_at=datetime.datetime(2024, 8, 13, 13, 3, 43,    │ │
# │ │                                277352))                                                      │ │
# │ │             dataset_progress = {'total': 1000, 'completed': 0, 'pending': 1000}              │ │
# │ │                     datetime = <class 'datetime.datetime'>                                   │ │
# │ │              delete_response = <function delete_response at 0x3498aaa20>                     │ │
# │ │                           ds = DatasetDict({                                                 │ │
# │ │                                │   train: Dataset({                                          │ │
# │ │                                │   │   features: ['input persona', 'synthesized text',       │ │
# │ │                                'description'],                                               │ │
# │ │                                │   │   num_rows: 50000                                       │ │
# │ │                                │   })                                                        │ │
# │ │                                })                                                            │ │
# │ │                         exit = <IPython.core.autocall.ZMQExitAutocall object at 0x109dcd010> │ │
# │ │         get_dataset_progress = <function get_dataset_progress at 0x13a49df80>                │ │
# │ │                  get_ipython = <bound method InteractiveShell.get_ipython of                 │ │
# │ │                                <ipykernel.zmqshell.ZMQInteractiveShell object at             │ │
# │ │                                0x109dbc750>>                                                 │ │
# │ │                           In = [                                                             │ │
# │ │                                │   '',                                                       │ │
# │ │                                │   'import argilla as rg\n\nclient =                         │ │
# │ │                                rg.Argilla(api_key="argilla.apikey", api_url="htt'+20,        │ │
# │ │                                │   'from datetime import datetime\n\ndataset = rg.Dataset(\n │ │
# │ │                                name=f"triggers_{dateti'+730,                                 │ │
# │ │                                │   'dataset.create()',                                       │ │
# │ │                                │   'dataset.records.log(\n    records=[\n                    │ │
# │ │                                rg.Record(\n            fields={\n     '+178,                 │ │
# │ │                                │   'list(\n    dataset.records(\n                            │ │
# │ │                                query=rg.Query(filter=rg.Filter(conditions=[('+43,            │ │
# │ │                                │   'from distilabel.llms import InferenceEndpointsLLM\nfrom  │ │
# │ │                                distilabel.steps.tasks im'+1607,                              │ │
# │ │                                │   'from distilabel.llms import InferenceEndpointsLLM\nfrom  │ │
# │ │                                distilabel.steps.tasks im'+1255,                              │ │
# │ │                                │   'def respond_to_good_instructions() -> None:\n            │ │
# │ │                                updated_records = []\n    for rec'+707,                       │ │
# │ │                                │   'def get_dataset_progress(dataset_id):\n    url =         │ │
# │ │                                f"http://localhost:6900/api/v1/d'+550,                        │ │
# │ │                                │   ... +25                                                   │ │
# │ │                                ]                                                             │ │
# │ │        InferenceEndpointsLLM = <class                                                        │ │
# │ │                                'distilabel.llms.huggingface.inference_endpoints.InferenceEn… │ │
# │ │                 load_dataset = <function load_dataset at 0x119893ec0>                        │ │
# │ │                  MAX_RECORDS = 1000                                                          │ │
# │ │                         open = <function open at 0x1079ea660>                                │ │
# │ │                          Out = {                                                             │ │
# │ │                                │   3:                                                        │ │
# │ │                                Dataset(id=UUID('b1c45402-26c8-47ac-8615-703a58b06469')       │ │
# │ │                                inserted_at=datetime.datetime(2024, 8, 13, 9, 10, 55, 139663) │ │
# │ │                                updated_at=datetime.datetime(2024, 8, 13, 9, 10, 55, 338173)  │ │
# │ │                                name='triggers_20240813111053' status='ready' guidelines=None │ │
# │ │                                allow_extra_metadata=False                                    │ │
# │ │                                distribution=OverlapTaskDistributionModel(strategy='overlap', │ │
# │ │                                min_submitted=1)                                              │ │
# │ │                                workspace_id=UUID('735cae0d-eb08-45c3-ad79-0a11ad4dd2c2')     │ │
# │ │                                last_activity_at=datetime.datetime(2024, 8, 13, 9, 10, 55,    │ │
# │ │                                338173)),                                                     │ │
# │ │                                │   4:                                                        │ │
# │ │                                DatasetRecords(Dataset(id=UUID('b1c45402-26c8-47ac-8615-703a… │ │
# │ │                                inserted_at=datetime.datetime(2024, 8, 13, 9, 10, 55, 139663) │ │
# │ │                                updated_at=datetime.datetime(2024, 8, 13, 9, 10, 55, 338173)  │ │
# │ │                                name='triggers_20240813111053' status='ready' guidelines=None │ │
# │ │                                allow_extra_metadata=False                                    │ │
# │ │                                distribution=OverlapTaskDistributionModel(strategy='overlap', │ │
# │ │                                min_submitted=1)                                              │ │
# │ │                                workspace_id=UUID('735cae0d-eb08-45c3-ad79-0a11ad4dd2c2')     │ │
# │ │                                last_activity_at=datetime.datetime(2024, 8, 13, 9, 10, 55,    │ │
# │ │                                338173))),                                                    │ │
# │ │                                │   5: [],                                                    │ │
# │ │                                │   18:                                                       │ │
# │ │                                Dataset(id=UUID('4891f4e1-86fd-4f83-bb45-63d6374a71fa')       │ │
# │ │                                inserted_at=datetime.datetime(2024, 8, 13, 9, 22, 53, 35302)  │ │
# │ │                                updated_at=datetime.datetime(2024, 8, 13, 9, 22, 53, 217360)  │ │
# │ │                                name='triggers_20240813112252' status='ready' guidelines=None │ │
# │ │                                allow_extra_metadata=False                                    │ │
# │ │                                distribution=OverlapTaskDistributionModel(strategy='overlap', │ │
# │ │                                min_submitted=1)                                              │ │
# │ │                                workspace_id=UUID('735cae0d-eb08-45c3-ad79-0a11ad4dd2c2')     │ │
# │ │                                last_activity_at=datetime.datetime(2024, 8, 13, 9, 22, 53,    │ │
# │ │                                217360)),                                                     │ │
# │ │                                │   19:                                                       │ │
# │ │                                DatasetRecords(Dataset(id=UUID('4891f4e1-86fd-4f83-bb45-63d6… │ │
# │ │                                inserted_at=datetime.datetime(2024, 8, 13, 9, 22, 53, 35302)  │ │
# │ │                                updated_at=datetime.datetime(2024, 8, 13, 9, 22, 53, 217360)  │ │
# │ │                                name='triggers_20240813112252' status='ready' guidelines=None │ │
# │ │                                allow_extra_metadata=False                                    │ │
# │ │                                distribution=OverlapTaskDistributionModel(strategy='overlap', │ │
# │ │                                min_submitted=1)                                              │ │
# │ │                                workspace_id=UUID('735cae0d-eb08-45c3-ad79-0a11ad4dd2c2')     │ │
# │ │                                last_activity_at=datetime.datetime(2024, 8, 13, 9, 22, 53,    │ │
# │ │                                217360))),                                                    │ │
# │ │                                │   20: [                                                     │ │
# │ │                                │   │                                                         │ │
# │ │                                Record(id=-9183889785302982381,status=completed,fields={'per… │ │
# │ │                                'A data analyst exploring patterns in transportation          │ │
# │ │                                infrastructure and its correlation with regional economic     │ │
# │ │                                growth.', 'instruction': 'What is the correlation coefficient │ │
# │ │                                between highway lane miles per capita and GDP growth rate in  │ │
# │ │                                metropolitan areas?', 'response1': '', 'response2':           │ │
# │ │                                ''},metadata={},suggestions={},responses={'respond':          │ │
# │ │                                [{'value': 'yes'}]})                                          │ │
# │ │                                │   ],                                                        │ │
# │ │                                │   29:                                                       │ │
# │ │                                Dataset(id=UUID('3453d11b-f50a-4f62-8d38-09ac3e99bc00')       │ │
# │ │                                inserted_at=datetime.datetime(2024, 8, 13, 13, 3, 43, 20806)  │ │
# │ │                                updated_at=datetime.datetime(2024, 8, 13, 13, 3, 43, 277352)  │ │
# │ │                                name='triggers_20240813150340' status='ready' guidelines=None │ │
# │ │                                allow_extra_metadata=False                                    │ │
# │ │                                distribution=OverlapTaskDistributionModel(strategy='overlap', │ │
# │ │                                min_submitted=1)                                              │ │
# │ │                                workspace_id=UUID('735cae0d-eb08-45c3-ad79-0a11ad4dd2c2')     │ │
# │ │                                last_activity_at=datetime.datetime(2024, 8, 13, 13, 3, 43,    │ │
# │ │                                277352)),                                                     │ │
# │ │                                │   30:                                                       │ │
# │ │                                DatasetRecords(Dataset(id=UUID('3453d11b-f50a-4f62-8d38-09ac… │ │
# │ │                                inserted_at=datetime.datetime(2024, 8, 13, 13, 3, 43, 20806)  │ │
# │ │                                updated_at=datetime.datetime(2024, 8, 13, 13, 3, 43, 277352)  │ │
# │ │                                name='triggers_20240813150340' status='ready' guidelines=None │ │
# │ │                                allow_extra_metadata=False                                    │ │
# │ │                                distribution=OverlapTaskDistributionModel(strategy='overlap', │ │
# │ │                                min_submitted=1)                                              │ │
# │ │                                workspace_id=UUID('735cae0d-eb08-45c3-ad79-0a11ad4dd2c2')     │ │
# │ │                                last_activity_at=datetime.datetime(2024, 8, 13, 13, 3, 43,    │ │
# │ │                                277352)))                                                     │ │
# │ │                                }                                                             │ │
# │ │                         quit = <IPython.core.autocall.ZMQExitAutocall object at 0x109dcd010> │ │
# │ │                       record = Record(id=7710131432211336391,status=pending,fields={'person… │ │
# │ │                                "A business analyst studying the fast-food industry's         │ │
# │ │                                expansion into niche markets and its impact on local food     │ │
# │ │                                culture.", 'instruction': "Can you provide a detailed         │ │
# │ │                                analysis of how popular fast-food chains like McDonald's and  │ │
# │ │                                Subway have adapted their menus to cater to the growing       │ │
# │ │                                demand for halal and vegan options in urban centers, and how  │ │
# │ │                                this trend is affecting the sales of traditional local        │ │
# │ │                                eateries in cities like London and New York?", 'response1':   │ │
# │ │                                '', 'response2': ''},metadata={},suggestions={},responses={}) │ │
# │ │            records_to_upload = [                                                             │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=-5760346988155005243,status=pending,fields={'perso… │ │
# │ │                                'A theater manager or events coordinator interested in        │ │
# │ │                                understanding the operational aspects, facilities, and        │ │
# │ │                                programming of performing arts centers, such as the Broward   │ │
# │ │                                Center.', 'instruction': 'What are the key considerations for │ │
# │ │                                scheduling and logistics when hosting a multi-show festival   │ │
# │ │                                at a performing arts center like the Broward Center?',        │ │
# │ │                                'response1': '', 'response2':                                 │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=-3625437124855111193,status=pending,fields={'perso… │ │
# │ │                                'An urban planner looking to understand the distribution and  │ │
# │ │                                organization of public services in the Halifax Regional       │ │
# │ │                                Municipality.', 'instruction': "Compare and contrast the      │ │
# │ │                                distribution of public services such as libraries, community  │ │
# │ │                                centers, and public transportation in different neighborhoods │ │
# │ │                                of Halifax, and discuss how the municipal government's urban  │ │
# │ │                                planning strategies impact access to these services for       │ │
# │ │                                residents of varying socioeconomic backgrounds.",             │ │
# │ │                                'response1': '', 'response2':                                 │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=8470971138878883928,status=pending,fields={'person… │ │
# │ │                                "A high school literature teacher looking for supplementary   │ │
# │ │                                materials to enrich their curriculum and provide students     │ │
# │ │                                with a deeper understanding of their state's cultural         │ │
# │ │                                heritage.", 'instruction': 'Can you provide me with a list of │ │
# │ │                                5-7 educational resources, including videos, articles, and    │ │
# │ │                                interactive websites, that explore the literary works and     │ │
# │ │                                cultural significance of Native American authors from my      │ │
# │ │                                state, such as Louise Erdrich or Sherman Alexie, to           │ │
# │ │                                incorporate into my 11th-grade American Literature curriculum │ │
# │ │                                and help my students better understand the cultural heritage  │ │
# │ │                                of our region?', 'response1': '', 'response2':                │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=5577758100684122665,status=pending,fields={'person… │ │
# │ │                                'A science fiction writer, exploring the use of secret trials │ │
# │ │                                as a theme in stories that examine surveillance, privacy, and │ │
# │ │                                power dynamics in society.', 'instruction': "In a dystopian   │ │
# │ │                                future, a young journalist named Maya discovers a hidden      │ │
# │ │                                underground network of secret trials, where the government    │ │
# │ │                                uses advanced surveillance technology to manipulate and       │ │
# │ │                                control citizens. As she delves deeper into the truth, she    │ │
# │ │                                realizes that her own sister was a victim of these trials and │ │
# │ │                                begins to question the true extent of the government's power. │ │
# │ │                                How can Maya use her skills as a journalist to expose the     │ │
# │ │                                secret trials and bring justice to those affected, while      │ │
# │ │                                navigating the treacherous landscape of government            │ │
# │ │                                surveillance and propaganda?", 'response1': '', 'response2':  │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=2438514324505934943,status=pending,fields={'person… │ │
# │ │                                'A financial analyst specializing in Asian markets and        │ │
# │ │                                wealthy individuals, interested in tracking the investments   │ │
# │ │                                and philanthropic activities of billionaires like Gerald      │ │
# │ │                                Chan.', 'instruction': "Gerald Chan's investment firm has     │ │
# │ │                                recently acquired a significant stake in a Chinese renewable  │ │
# │ │                                energy company. How might this investment impact the firm's   │ │
# │ │                                overall portfolio, and what potential philanthropic           │ │
# │ │                                opportunities might arise from this acquisition, particularly │ │
# │ │                                in the context of China's growing focus on sustainable        │ │
# │ │                                development?", 'response1': '', 'response2':                  │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=-3053034013413714191,status=pending,fields={'perso… │ │
# │ │                                'A high school physics teacher who enjoys applying physics    │ │
# │ │                                concepts to various sports, curious about the effects of      │ │
# │ │                                water resistance and body positioning in Paralympic           │ │
# │ │                                swimming.', 'instruction': 'How do the physical principles of │ │
# │ │                                drag and buoyancy influence the speed and efficiency of       │ │
# │ │                                Paralympic swimmers with different body types and             │ │
# │ │                                disabilities, and what techniques can coaches and athletes    │ │
# │ │                                use to optimize their performance in the water?',             │ │
# │ │                                'response1': '', 'response2':                                 │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=1475317635466170130,status=pending,fields={'person… │ │
# │ │                                'A high school physical education teacher seeking to          │ │
# │ │                                incorporate Paralympic history and achievements into the      │ │
# │ │                                curriculum to inspire and educate students about inclusivity  │ │
# │ │                                in sports.', 'instruction': 'How can I integrate the history  │ │
# │ │                                and achievements of Paralympic athletes into my physical      │ │
# │ │                                education lessons to promote inclusivity and diversity in     │ │
# │ │                                sports?', 'response1': '', 'response2':                       │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=2766392853323132520,status=pending,fields={'person… │ │
# │ │                                'A high school history teacher creating lesson plans on South │ │
# │ │                                American civilizations and their regional diversity.',        │ │
# │ │                                'instruction': 'Create a detailed lesson plan on the Inca     │ │
# │ │                                Empire, including its history, geography, and cultural        │ │
# │ │                                achievements, with a focus on comparing and contrasting its   │ │
# │ │                                development with that of the Aztec Empire in Mesoamerica.',   │ │
# │ │                                'response1': '', 'response2':                                 │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=6493508583017500999,status=pending,fields={'person… │ │
# │ │                                'A cultural anthropologist studying the representation and    │ │
# │ │                                adaptation of traditional folklore in contemporary media,     │ │
# │ │                                particularly in television and film.', 'instruction':         │ │
# │ │                                'Analyze the depiction of mythological creatures in modern TV │ │
# │ │                                shows and movies, exploring how folklore is reinterpreted and │ │
# │ │                                what cultural commentary is conveyed through these            │ │
# │ │                                representations.', 'response1': '', 'response2':              │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │                                                             │ │
# │ │                                Record(id=-1985739735303359649,status=pending,fields={'perso… │ │
# │ │                                'A high school earth science teacher looking for real-world   │ │
# │ │                                examples to explain climate zones, soil types, and            │ │
# │ │                                human-environment interactions.', 'instruction': 'Can you     │ │
# │ │                                provide some real-life examples of how climate zones, soil    │ │
# │ │                                types, and human activities intersect in different parts of   │ │
# │ │                                the world, such as the Amazon rainforest, the Sahara Desert,  │ │
# │ │                                or the Himalayan Mountains?', 'response1': '', 'response2':   │ │
# │ │                                ''},metadata={},suggestions={},responses={}),                 │ │
# │ │                                │   ... +990                                                  │ │
# │ │                                ]                                                             │ │
# │ │                     requests = <module 'requests' from                                       │ │
# │ │                                '/Users/ben/code/distilabel_trigger/.venv/lib/python3.11/sit… │ │
# │ │ respond_to_good_instructions = <function respond_to_good_instructions at 0x3498aac00>        │ │
# │ │            respond_to_record = <function respond_to_record at 0x1392f2c00>                   │ │
# │ │                           rg = <module 'argilla' from                                        │ │
# │ │                                '/Users/ben/code/distilabel_trigger/.venv/lib/python3.11/sit… │ │
# │ │                       sample = {                                                             │ │
# │ │                                │   'input persona': "A business analyst studying the         │ │
# │ │                                fast-food industry's expansion into niche market"+39,         │ │
# │ │                                │   'synthesized text': 'Can you provide a detailed analysis  │ │
# │ │                                of how popular fast-food chains like McDonal'+224,            │ │
# │ │                                │   'description': '0-shot instruction data synthesis'        │ │
# │ │                                }                                                             │ │
# │ │               TextGeneration = <class                                                        │ │
# │ │                                'distilabel.steps.tasks.text_generation.TextGeneration'>      │ │
# │ │                UltraFeedback = <class 'distilabel.steps.tasks.ultrafeedback.UltraFeedback'>  │ │
# │ │         update_record_fields = <function update_record_fields at 0x3498aad40>                │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ in get_dataset_progress:8                                                                        │
# │                                                                                                  │
# │    5 │   │   "X-Argilla-Api-Key": "argilla.apikey",                                              │
# │    6 │   │   "Content-Type": "application/json",                                                 │
# │    7 │   }                                                                                       │
# │ ❱  8 │   response = requests.get(url, headers=headers)                                           │
# │    9 │   return response.json()                                                                  │
# │   10                                                                                             │
# │   11                                                                                             │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ dataset_id = UUID('3453d11b-f50a-4f62-8d38-09ac3e99bc00')                                    │ │
# │ │    headers = {                                                                               │ │
# │ │              │   'accept': 'application/json',                                               │ │
# │ │              │   'X-Argilla-Api-Key': 'argilla.apikey',                                      │ │
# │ │              │   'Content-Type': 'application/json'                                          │ │
# │ │              }                                                                               │ │
# │ │        url = 'http://localhost:6900/api/v1/datasets/3453d11b-f50a-4f62-8d38-09ac3e99bc00/pr… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/ben/code/distilabel_trigger/.venv/lib/python3.11/site-packages/requests/api.py:73 in get  │
# │                                                                                                  │
# │    70 │   :rtype: requests.Response                                                              │
# │    71 │   """                                                                                    │
# │    72 │                                                                                          │
# │ ❱  73 │   return request("get", url, params=params, **kwargs)                                    │
# │    74                                                                                            │
# │    75                                                                                            │
# │    76 def options(url, **kwargs):                                                                │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ kwargs = {                                                                                   │ │
# │ │          │   'headers': {                                                                    │ │
# │ │          │   │   'accept': 'application/json',                                               │ │
# │ │          │   │   'X-Argilla-Api-Key': 'argilla.apikey',                                      │ │
# │ │          │   │   'Content-Type': 'application/json'                                          │ │
# │ │          │   }                                                                               │ │
# │ │          }                                                                                   │ │
# │ │ params = None                                                                                │ │
# │ │    url = 'http://localhost:6900/api/v1/datasets/3453d11b-f50a-4f62-8d38-09ac3e99bc00/progr'… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/ben/code/distilabel_trigger/.venv/lib/python3.11/site-packages/requests/api.py:59 in      │
# │ request                                                                                          │
# │                                                                                                  │
# │    56 │   # avoid leaving sockets open which can trigger a ResourceWarning in some               │
# │    57 │   # cases, and look like a memory leak in others.                                        │
# │    58 │   with sessions.Session() as session:                                                    │
# │ ❱  59 │   │   return session.request(method=method, url=url, **kwargs)                           │
# │    60                                                                                            │
# │    61                                                                                            │
# │    62 def get(url, params=None, **kwargs):                                                       │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │  kwargs = {                                                                                  │ │
# │ │           │   'params': None,                                                                │ │
# │ │           │   'headers': {                                                                   │ │
# │ │           │   │   'accept': 'application/json',                                              │ │
# │ │           │   │   'X-Argilla-Api-Key': 'argilla.apikey',                                     │ │
# │ │           │   │   'Content-Type': 'application/json'                                         │ │
# │ │           │   }                                                                              │ │
# │ │           }                                                                                  │ │
# │ │  method = 'get'                                                                              │ │
# │ │ session = <requests.sessions.Session object at 0x139b61910>                                  │ │
# │ │     url = 'http://localhost:6900/api/v1/datasets/3453d11b-f50a-4f62-8d38-09ac3e99bc00/progr… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/ben/code/distilabel_trigger/.venv/lib/python3.11/site-packages/requests/sessions.py:589   │
# │ in request                                                                                       │
# │                                                                                                  │
# │   586 │   │   │   "allow_redirects": allow_redirects,                                            │
# │   587 │   │   }                                                                                  │
# │   588 │   │   send_kwargs.update(settings)                                                       │
# │ ❱ 589 │   │   resp = self.send(prep, **send_kwargs)                                              │
# │   590 │   │                                                                                      │
# │   591 │   │   return resp                                                                        │
# │   592                                                                                            │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ allow_redirects = True                                                                       │ │
# │ │            auth = None                                                                       │ │
# │ │            cert = None                                                                       │ │
# │ │         cookies = None                                                                       │ │
# │ │            data = None                                                                       │ │
# │ │           files = None                                                                       │ │
# │ │         headers = {                                                                          │ │
# │ │                   │   'accept': 'application/json',                                          │ │
# │ │                   │   'X-Argilla-Api-Key': 'argilla.apikey',                                 │ │
# │ │                   │   'Content-Type': 'application/json'                                     │ │
# │ │                   }                                                                          │ │
# │ │           hooks = None                                                                       │ │
# │ │            json = None                                                                       │ │
# │ │          method = 'get'                                                                      │ │
# │ │          params = None                                                                       │ │
# │ │            prep = <PreparedRequest [GET]>                                                    │ │
# │ │         proxies = {}                                                                         │ │
# │ │             req = <Request [GET]>                                                            │ │
# │ │            self = <requests.sessions.Session object at 0x139b61910>                          │ │
# │ │     send_kwargs = {                                                                          │ │
# │ │                   │   'timeout': None,                                                       │ │
# │ │                   │   'allow_redirects': True,                                               │ │
# │ │                   │   'proxies': OrderedDict(),                                              │ │
# │ │                   │   'stream': False,                                                       │ │
# │ │                   │   'verify': True,                                                        │ │
# │ │                   │   'cert': None                                                           │ │
# │ │                   }                                                                          │ │
# │ │        settings = {'proxies': OrderedDict(), 'stream': False, 'verify': True, 'cert': None}  │ │
# │ │          stream = None                                                                       │ │
# │ │         timeout = None                                                                       │ │
# │ │             url = 'http://localhost:6900/api/v1/datasets/3453d11b-f50a-4f62-8d38-09ac3e99bc… │ │
# │ │          verify = None                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/ben/code/distilabel_trigger/.venv/lib/python3.11/site-packages/requests/sessions.py:703   │
# │ in send                                                                                          │
# │                                                                                                  │
# │   700 │   │   start = preferred_clock()                                                          │
# │   701 │   │                                                                                      │
# │   702 │   │   # Send the request                                                                 │
# │ ❱ 703 │   │   r = adapter.send(request, **kwargs)                                                │
# │   704 │   │                                                                                      │
# │   705 │   │   # Total elapsed time of the request (approximately)                                │
# │   706 │   │   elapsed = preferred_clock() - start                                                │
# │                                                                                                  │
# │ ╭──────────────────────────────── locals ─────────────────────────────────╮                      │
# │ │         adapter = <requests.adapters.HTTPAdapter object at 0x139bbcc50> │                      │
# │ │ allow_redirects = True                                                  │                      │
# │ │           hooks = {'response': []}                                      │                      │
# │ │          kwargs = {                                                     │                      │
# │ │                   │   'timeout': None,                                  │                      │
# │ │                   │   'proxies': OrderedDict(),                         │                      │
# │ │                   │   'stream': False,                                  │                      │
# │ │                   │   'verify': True,                                   │                      │
# │ │                   │   'cert': None                                      │                      │
# │ │                   }                                                     │                      │
# │ │         request = <PreparedRequest [GET]>                               │                      │
# │ │            self = <requests.sessions.Session object at 0x139b61910>     │                      │
# │ │           start = 1723557907.587455                                     │                      │
# │ │          stream = False                                                 │                      │
# │ ╰─────────────────────────────────────────────────────────────────────────╯                      │
# │                                                                                                  │
# │ /Users/ben/code/distilabel_trigger/.venv/lib/python3.11/site-packages/requests/adapters.py:667   │
# │ in send                                                                                          │
# │                                                                                                  │
# │   664 │   │   │   timeout = TimeoutSauce(connect=timeout, read=timeout)                          │
# ...
# │ │     assert_same_host = False                                                                 │ │
# │ │                 body = None                                                                  │ │
# │ │             body_pos = None                                                                  │ │
# │ │              chunked = False                                                                 │ │
# │ │           clean_exit = False                                                                 │ │
# │ │                 conn = None                                                                  │ │
# │ │       decode_content = False                                                                 │ │
# │ │   destination_scheme = None                                                                  │ │
# │ │                  err = None                                                                  │ │
# │ │              headers = {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip,    │ │
# │ │                        deflate', 'accept': 'application/json', 'Connection': 'keep-alive',   │ │
# │ │                        'X-Argilla-Api-Key': 'argilla.apikey', 'Content-Type':                │ │
# │ │                        'application/json'}                                                   │ │
# │ │ http_tunnel_required = False                                                                 │ │
# │ │               method = 'GET'                                                                 │ │
# │ │           parsed_url = Url(                                                                  │ │
# │ │                        │   scheme=None,                                                      │ │
# │ │                        │   auth=None,                                                        │ │
# │ │                        │   host=None,                                                        │ │
# │ │                        │   port=None,                                                        │ │
# │ │                        │                                                                     │ │
# │ │                        path='/api/v1/datasets/3453d11b-f50a-4f62-8d38-09ac3e99bc00/progress… │ │
# │ │                        │   query=None,                                                       │ │
# │ │                        │   fragment=None                                                     │ │
# │ │                        )                                                                     │ │
# │ │         pool_timeout = None                                                                  │ │
# │ │      preload_content = False                                                                 │ │
# │ │             redirect = False                                                                 │ │
# │ │         release_conn = False                                                                 │ │
# │ │    release_this_conn = True                                                                  │ │
# │ │        response_conn = <urllib3.connection.HTTPConnection object at 0x3498eb8d0>             │ │
# │ │          response_kw = {}                                                                    │ │
# │ │              retries = Retry(total=0, connect=None, read=False, redirect=None, status=None)  │ │
# │ │                 self = <urllib3.connectionpool.HTTPConnectionPool object at 0x13a26a890>     │ │
# │ │              timeout = Timeout(connect=None, read=None, total=None)                          │ │
# │ │          timeout_obj = Timeout(connect=None, read=None, total=None)                          │ │
# │ │                  url = '/api/v1/datasets/3453d11b-f50a-4f62-8d38-09ac3e99bc00/progress'      │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/ben/code/distilabel_trigger/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py: │
# │ 536 in _make_request                                                                             │
# │                                                                                                  │
# │    533 │   │                                                                                     │
# │    534 │   │   # Receive the response from the server                                            │
# │    535 │   │   try:                                                                              │
# │ ❱  536 │   │   │   response = conn.getresponse()                                                 │
# │    537 │   │   except (BaseSSLError, OSError) as e:                                              │
# │    538 │   │   │   self._raise_timeout(err=e, url=url, timeout_value=read_timeout)               │
# │    539 │   │   │   raise                                                                         │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │                   body = None                                                                │ │
# │ │                chunked = False                                                               │ │
# │ │                   conn = <urllib3.connection.HTTPConnection object at 0x3498eb8d0>           │ │
# │ │         decode_content = False                                                               │ │
# │ │ enforce_content_length = True                                                                │ │
# │ │                headers = {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip,  │ │
# │ │                          deflate', 'accept': 'application/json', 'Connection': 'keep-alive', │ │
# │ │                          'X-Argilla-Api-Key': 'argilla.apikey', 'Content-Type':              │ │
# │ │                          'application/json'}                                                 │ │
# │ │                 method = 'GET'                                                               │ │
# │ │        preload_content = False                                                               │ │
# │ │           read_timeout = None                                                                │ │
# │ │          response_conn = <urllib3.connection.HTTPConnection object at 0x3498eb8d0>           │ │
# │ │                retries = Retry(total=0, connect=None, read=False, redirect=None,             │ │
# │ │                          status=None)                                                        │ │
# │ │                   self = <urllib3.connectionpool.HTTPConnectionPool object at 0x13a26a890>   │ │
# │ │                timeout = Timeout(connect=None, read=None, total=None)                        │ │
# │ │            timeout_obj = Timeout(connect=None, read=None, total=None)                        │ │
# │ │                    url = '/api/v1/datasets/3453d11b-f50a-4f62-8d38-09ac3e99bc00/progress'    │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/ben/code/distilabel_trigger/.venv/lib/python3.11/site-packages/urllib3/connection.py:464  │
# │ in getresponse                                                                                   │
# │                                                                                                  │
# │   461 │   │   from .response import HTTPResponse                                                 │
# │   462 │   │                                                                                      │
# │   463 │   │   # Get the response from http.client.HTTPConnection                                 │
# │ ❱ 464 │   │   httplib_response = super().getresponse()                                           │
# │   465 │   │                                                                                      │
# │   466 │   │   try:                                                                               │
# │   467 │   │   │   assert_header_parsing(httplib_response.msg)                                    │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ HTTPResponse = <class 'urllib3.response.HTTPResponse'>                                       │ │
# │ │ resp_options = _ResponseOptions(                                                             │ │
# │ │                │   request_method='GET',                                                     │ │
# │ │                │                                                                             │ │
# │ │                request_url='/api/v1/datasets/3453d11b-f50a-4f62-8d38-09ac3e99bc00/progress', │ │
# │ │                │   preload_content=False,                                                    │ │
# │ │                │   decode_content=False,                                                     │ │
# │ │                │   enforce_content_length=True                                               │ │
# │ │                )                                                                             │ │
# │ │         self = <urllib3.connection.HTTPConnection object at 0x3498eb8d0>                     │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11 │
# │ /http/client.py:1395 in getresponse                                                              │
# │                                                                                                  │
# │   1392 │   │                                                                                     │
# │   1393 │   │   try:                                                                              │
# │   1394 │   │   │   try:                                                                          │
# │ ❱ 1395 │   │   │   │   response.begin()                                                          │
# │   1396 │   │   │   except ConnectionError:                                                       │
# │   1397 │   │   │   │   self.close()                                                              │
# │   1398 │   │   │   │   raise                                                                     │
# │                                                                                                  │
# │ ╭─────────────────────────────── locals ───────────────────────────────╮                         │
# │ │ response = <http.client.HTTPResponse object at 0x13d082530>          │                         │
# │ │     self = <urllib3.connection.HTTPConnection object at 0x3498eb8d0> │                         │
# │ ╰──────────────────────────────────────────────────────────────────────╯                         │
# │                                                                                                  │
# │ /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11 │
# │ /http/client.py:325 in begin                                                                     │
# │                                                                                                  │
# │    322 │   │                                                                                     │
# │    323 │   │   # read until we get a non-100 response                                            │
# │    324 │   │   while True:                                                                       │
# │ ❱  325 │   │   │   version, status, reason = self._read_status()                                 │
# │    326 │   │   │   if status != CONTINUE:                                                        │
# │    327 │   │   │   │   break                                                                     │
# │    328 │   │   │   # skip the header from the 100 response                                       │
# │                                                                                                  │
# │ ╭──────────────────────── locals ─────────────────────────╮                                      │
# │ │ self = <http.client.HTTPResponse object at 0x13d082530> │                                      │
# │ ╰─────────────────────────────────────────────────────────╯                                      │
# │                                                                                                  │
# │ /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11 │
# │ /http/client.py:286 in _read_status                                                              │
# │                                                                                                  │
# │    283 │   │   self.will_close = _UNKNOWN      # conn will close at end of response              │
# │    284 │                                                                                         │
# │    285 │   def _read_status(self):                                                               │
# │ ❱  286 │   │   line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")                          │
# │    287 │   │   if len(line) > _MAXLINE:                                                          │
# │    288 │   │   │   raise LineTooLong("status line")                                              │
# │    289 │   │   if self.debuglevel > 0:                                                           │
# │                                                                                                  │
# │ ╭──────────────────────── locals ─────────────────────────╮                                      │
# │ │ self = <http.client.HTTPResponse object at 0x13d082530> │                                      │
# │ ╰─────────────────────────────────────────────────────────╯                                      │
# │                                                                                                  │
# │ /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11 │
# │ /socket.py:706 in readinto                                                                       │
# │                                                                                                  │
# │   703 │   │   │   raise OSError("cannot read from timed out object")                             │
# │   704 │   │   while True:                                                                        │
# │   705 │   │   │   try:                                                                           │
# │ ❱ 706 │   │   │   │   return self._sock.recv_into(b)                                             │
# │   707 │   │   │   except timeout:                                                                │
# │   708 │   │   │   │   self._timeout_occurred = True                                              │
# │   709 │   │   │   │   raise                                                                      │
# │                                                                                                  │
# │ ╭──────────────────── locals ────────────────────╮                                               │
# │ │    b = <memory at 0x34984f880>                 │                                               │
# │ │ self = <socket.SocketIO object at 0x13d081780> │                                               │
# │ ╰────────────────────────────────────────────────╯                                               │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
